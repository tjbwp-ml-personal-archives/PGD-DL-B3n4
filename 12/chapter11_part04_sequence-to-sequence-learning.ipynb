# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# ## Beyond text classification: Sequence-to-sequence learning

# %% [markdown]
# ### A machine translation example

# %%
# !wget http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# !unzip -q spa-eng.zip
# Out:
# --2023-11-15 13:54:59--  http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.142.207, 74.125.195.207, 172.253.117.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.142.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2638744 (2.5M) [application/zip]
# Saving to: ‘spa-eng.zip’
#
# spa-eng.zip         100%[===================>]   2.52M  --.-KB/s    in 0.01s
#
# 2023-11-15 13:54:59 (233 MB/s) - ‘spa-eng.zip’ saved [2638744/2638744]

# %%
text_file = "spa-eng/spa.txt"
with open(text_file) as f:
    lines = f.read().split("\n")[:-1]
text_pairs = []
for line in lines:
    english, spanish = line.split("\t")
    spanish = "[start] " + spanish + " [end]"
    text_pairs.append((english, spanish))

# %%
import random
print(random.choice(text_pairs))
# Out:
# ("This isn't French.", '[start] Esto no es francés. [end]')

# %%
import random
random.shuffle(text_pairs)
num_val_samples = int(0.15 * len(text_pairs))
num_train_samples = len(text_pairs) - 2 * num_val_samples

train_pairs = text_pairs[:num_train_samples]
val_pairs = text_pairs[num_train_samples:num_train_samples + num_val_samples]
test_pairs = text_pairs[num_train_samples + num_val_samples:]

# %% [markdown]
# **Vectorizing the English and Spanish text pairs**

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
import string
import re

strip_chars = string.punctuation + "¿"
strip_chars = strip_chars.replace("[", "")
strip_chars = strip_chars.replace("]", "")

def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(
        lowercase, f"[{re.escape(strip_chars)}]", "")

vocab_size = 15000
sequence_length = 20

source_vectorization = layers.TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
target_vectorization = layers.TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length + 1,
    standardize=custom_standardization,
)
train_english_texts = [pair[0] for pair in train_pairs]
train_spanish_texts = [pair[1] for pair in train_pairs]
source_vectorization.adapt(train_english_texts)
target_vectorization.adapt(train_spanish_texts)

# %% [markdown]
# **Preparing datasets for the translation task**

# %%
batch_size = 64

def format_dataset(eng, spa):
    eng = source_vectorization(eng)
    spa = target_vectorization(spa)
    return ({
        "english": eng,
        "spanish": spa[:, :-1],
    }, spa[:, 1:])

def make_dataset(pairs):
    eng_texts, spa_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    spa_texts = list(spa_texts)
    dataset = tf.data.Dataset.from_tensor_slices((eng_texts, spa_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset, num_parallel_calls=4)
    return dataset.shuffle(2048).prefetch(16).cache()

train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %%
for inputs, targets in train_ds.take(1):
    print(f"inputs['english'].shape: {inputs['english'].shape}")
    print(f"inputs['spanish'].shape: {inputs['spanish'].shape}")
    print(f"targets.shape: {targets.shape}")
# Out:
# inputs['english'].shape: (64, 20)
# inputs['spanish'].shape: (64, 20)
# targets.shape: (64, 20)

# %% [markdown]
# ### Sequence-to-sequence learning with RNNs

# %% [markdown]
# **GRU-based encoder**

# %%
from tensorflow import keras
from tensorflow.keras import layers

embed_dim = 256
latent_dim = 1024

source = keras.Input(shape=(None,), dtype="int64", name="english")
x = layers.Embedding(vocab_size, embed_dim, mask_zero=True)(source)
encoded_source = layers.Bidirectional(
    layers.GRU(latent_dim), merge_mode="sum")(x)

# %% [markdown]
# **GRU-based decoder and the end-to-end model**

# %%
past_target = keras.Input(shape=(None,), dtype="int64", name="spanish")
x = layers.Embedding(vocab_size, embed_dim, mask_zero=True)(past_target)
decoder_gru = layers.GRU(latent_dim, return_sequences=True)
x = decoder_gru(x, initial_state=encoded_source)
x = layers.Dropout(0.5)(x)
target_next_step = layers.Dense(vocab_size, activation="softmax")(x)
seq2seq_rnn = keras.Model([source, past_target], target_next_step)

# %% [markdown]
# **Training our recurrent sequence-to-sequence model**

# %%
seq2seq_rnn.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
seq2seq_rnn.fit(train_ds, epochs=15, validation_data=val_ds)
# Out:
# Epoch 1/15
# 1302/1302 [==============================] - 139s 92ms/step - loss: 4.6832 - accuracy: 0.3182 - val_loss: 3.9008 - val_accuracy: 0.3912
# Epoch 2/15
# 1302/1302 [==============================] - 109s 84ms/step - loss: 3.7234 - accuracy: 0.4152 - val_loss: 3.2452 - val_accuracy: 0.4715
# Epoch 3/15
# 1302/1302 [==============================] - 109s 84ms/step - loss: 3.2120 - accuracy: 0.4727 - val_loss: 2.8643 - val_accuracy: 0.5204
# Epoch 4/15
# 1302/1302 [==============================] - 109s 83ms/step - loss: 2.8558 - accuracy: 0.5130 - val_loss: 2.6228 - val_accuracy: 0.5525
# Epoch 5/15
# 1302/1302 [==============================] - 109s 83ms/step - loss: 2.5782 - accuracy: 0.5468 - val_loss: 2.4384 - val_accuracy: 0.5794
# Epoch 6/15
# 1302/1302 [==============================] - 108s 83ms/step - loss: 2.3520 - accuracy: 0.5759 - val_loss: 2.3024 - val_accuracy: 0.5998
# Epoch 7/15
# 1302/1302 [==============================] - 109s 83ms/step - loss: 2.1650 - accuracy: 0.6007 - val_loss: 2.2106 - val_accuracy: 0.6132
# Epoch 8/15
# 1302/1302 [==============================] - 108s 83ms/step - loss: 2.0038 - accuracy: 0.6218 - val_loss: 2.1373 - val_accuracy: 0.6250
# Epoch 9/15
# 1302/1302 [==============================] - 108s 83ms/step - loss: 1.8701 - accuracy: 0.6399 - val_loss: 2.0874 - val_accuracy: 0.6318
# Epoch 10/15
# 1302/1302 [==============================] - 109s 83ms/step - loss: 1.7439 - accuracy: 0.6577 - val_loss: 2.0408 - val_accuracy: 0.6397
# Epoch 11/15
# 1302/1302 [==============================] - 108s 83ms/step - loss: 1.6397 - accuracy: 0.6720 - val_loss: 2.0042 - val_accuracy: 0.6462
# Epoch 12/15
# 1302/1302 [==============================] - 110s 84ms/step - loss: 1.5478 - accuracy: 0.6849 - val_loss: 1.9807 - val_accuracy: 0.6502
# Epoch 13/15
# 1302/1302 [==============================] - 108s 83ms/step - loss: 1.4678 - accuracy: 0.6965 - val_loss: 1.9640 - val_accuracy: 0.6537
# Epoch 14/15
# 1302/1302 [==============================] - 108s 83ms/step - loss: 1.3960 - accuracy: 0.7076 - val_loss: 1.9476 - val_accuracy: 0.6566
# Epoch 15/15
# 1302/1302 [==============================] - 108s 83ms/step - loss: 1.3324 - accuracy: 0.7169 - val_loss: 1.9298 - val_accuracy: 0.6587

# %% [markdown]
# **Translating new sentences with our RNN encoder and decoder**

# %%
import numpy as np
spa_vocab = target_vectorization.get_vocabulary()
spa_index_lookup = dict(zip(range(len(spa_vocab)), spa_vocab))
max_decoded_sentence_length = 20

def decode_sequence(input_sentence):
    tokenized_input_sentence = source_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = target_vectorization([decoded_sentence])
        next_token_predictions = seq2seq_rnn.predict(
            [tokenized_input_sentence, tokenized_target_sentence])
        sampled_token_index = np.argmax(next_token_predictions[0, i, :])
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token
        if sampled_token == "[end]":
            break
    return decoded_sentence

test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(20):
    input_sentence = random.choice(test_eng_texts)
    print("-")
    print(input_sentence)
    print(decode_sequence(input_sentence))
# Out:
# -
# He broke the window on purpose.
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# [start] Él rompió la ventana a propósito [end]
# -
# We came here to enjoy ourselves.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# [start] vinimos a que nos [UNK] [end]
# -
# There is no use crying for help. No one will hear you.
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# [start] no hay ni siquiera [UNK] para nadie [UNK] [end]
# -
# Tom and Mary are flying to Boston tomorrow.
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] tom y mary están planeando boston mañana [end]
# -
# Tom threatened us.
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# [start] tom nos [UNK] [end]
# -
# She has traveled all over the globe.
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# [start] ella ha viajado por todo el mundo [end]
# -
# Who do you live with?
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# [start] con quién viven [end]
# -
# When did you last see Tom?
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# [start] cuándo viste la última vez [end]
# -
# You don't usually do that by yourself, do you?
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# [start] no te hagas eso solo verdad [end]
# -
# He knows how to swim.
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# [start] Él sabe cómo nadar [end]
# -
# Don't get caught.
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# [start] no te [UNK] [end]
# -
# I'm sorry, I just wanted to help.
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# [start] lo siento que debería ayudar [end]
# -
# There were two red hats on this table two hours ago.
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# [start] había dos [UNK] de esta habitación hace dos horas atrás [end]
# -
# Mom, where's my handkerchief?
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# [start] mamá es mi escritorio [end]
# -
# The teacher made him stay after school.
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# [start] el profesor se puso a la escuela después de la escuela [end]
# -
# Where does that bus go?
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# [start] dónde va el próximo [end]
# -
# The doctor told Tom that he should eat a lot of vegetables.
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# [start] el médico le dijo a tom que tenía muchas cosas a los animales [end]
# -
# Can you throw a fastball?
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# [start] puedes [UNK] una [UNK] [end]
# -
# It's totally my fault.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# [start] es culpa mía [end]
# -
# The pilot hinted that it might be a UFO.
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# [start] el [UNK] de que sea que sea un [UNK] [end]

# %% [markdown]
# ### Sequence-to-sequence learning with Transformer

# %% [markdown]
# #### The Transformer decoder

# %% [markdown]
# **The `TransformerDecoder`**

# %%
class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1),
             tf.constant([1, 1], dtype=tf.int32)], axis=0)
        return tf.tile(mask, mult)

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(
                mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)
        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=causal_mask)
        attention_output_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(
            query=attention_output_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        attention_output_2 = self.layernorm_2(
            attention_output_1 + attention_output_2)
        proj_output = self.dense_proj(attention_output_2)
        return self.layernorm_3(attention_output_2 + proj_output)

# %% [markdown]
# #### Putting it all together: A Transformer for machine translation

# %% [markdown]
# **PositionalEmbedding layer**

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, input_dim, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=input_dim, output_dim=output_dim)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim)
        self.sequence_length = sequence_length
        self.input_dim = input_dim
        self.output_dim = output_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

    def get_config(self):
        config = super(PositionalEmbedding, self).get_config()
        config.update({
            "output_dim": self.output_dim,
            "sequence_length": self.sequence_length,
            "input_dim": self.input_dim,
        })
        return config

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]
        attention_output = self.attention(
            inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

# %% [markdown]
# **End-to-end Transformer**

# %%
embed_dim = 256
dense_dim = 2048
num_heads = 8

encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="english")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(encoder_inputs)
encoder_outputs = TransformerEncoder(embed_dim, dense_dim, num_heads)(x)

decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="spanish")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(decoder_inputs)
x = TransformerDecoder(embed_dim, dense_dim, num_heads)(x, encoder_outputs)
x = layers.Dropout(0.5)(x)
decoder_outputs = layers.Dense(vocab_size, activation="softmax")(x)
transformer = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# **Training the sequence-to-sequence Transformer**

# %%
transformer.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
transformer.fit(train_ds, epochs=30, validation_data=val_ds)
# Out:
# Epoch 1/30
# 1302/1302 [==============================] - 103s 75ms/step - loss: 3.7901 - accuracy: 0.4405 - val_loss: 2.8990 - val_accuracy: 0.5343
# Epoch 2/30
# 1302/1302 [==============================] - 91s 70ms/step - loss: 2.8469 - accuracy: 0.5502 - val_loss: 2.5115 - val_accuracy: 0.5906
# Epoch 3/30
# 1302/1302 [==============================] - 89s 69ms/step - loss: 2.5544 - accuracy: 0.5935 - val_loss: 2.4160 - val_accuracy: 0.6058
# Epoch 4/30
# 1302/1302 [==============================] - 90s 69ms/step - loss: 2.3919 - accuracy: 0.6197 - val_loss: 2.3144 - val_accuracy: 0.6283
# Epoch 5/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 2.2854 - accuracy: 0.6380 - val_loss: 2.3050 - val_accuracy: 0.6319
# Epoch 6/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 2.2142 - accuracy: 0.6518 - val_loss: 2.3009 - val_accuracy: 0.6396
# Epoch 7/30
# 1302/1302 [==============================] - 90s 69ms/step - loss: 2.1475 - accuracy: 0.6644 - val_loss: 2.2839 - val_accuracy: 0.6465
# Epoch 8/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 2.0796 - accuracy: 0.6772 - val_loss: 2.2376 - val_accuracy: 0.6517
# Epoch 9/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 2.0192 - accuracy: 0.6890 - val_loss: 2.2238 - val_accuracy: 0.6609
# Epoch 10/30
# 1302/1302 [==============================] - 90s 69ms/step - loss: 1.9734 - accuracy: 0.6974 - val_loss: 2.2473 - val_accuracy: 0.6580
# Epoch 11/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 1.9358 - accuracy: 0.7041 - val_loss: 2.2658 - val_accuracy: 0.6535
# Epoch 12/30
# 1302/1302 [==============================] - 89s 69ms/step - loss: 1.9027 - accuracy: 0.7104 - val_loss: 2.2402 - val_accuracy: 0.6681
# Epoch 13/30
# 1302/1302 [==============================] - 90s 69ms/step - loss: 1.8771 - accuracy: 0.7154 - val_loss: 2.2430 - val_accuracy: 0.6670
# Epoch 14/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 1.8534 - accuracy: 0.7198 - val_loss: 2.2719 - val_accuracy: 0.6691
# Epoch 15/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 1.8319 - accuracy: 0.7230 - val_loss: 2.2705 - val_accuracy: 0.6664
# Epoch 16/30
# 1302/1302 [==============================] - 90s 69ms/step - loss: 1.8131 - accuracy: 0.7271 - val_loss: 2.3075 - val_accuracy: 0.6673
# Epoch 17/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 1.7959 - accuracy: 0.7301 - val_loss: 2.2892 - val_accuracy: 0.6674
# Epoch 18/30
# 1302/1302 [==============================] - 89s 69ms/step - loss: 1.7778 - accuracy: 0.7337 - val_loss: 2.3120 - val_accuracy: 0.6700
# Epoch 19/30
# 1302/1302 [==============================] - 90s 69ms/step - loss: 1.7619 - accuracy: 0.7368 - val_loss: 2.3163 - val_accuracy: 0.6709
# Epoch 20/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 1.7461 - accuracy: 0.7390 - val_loss: 2.3504 - val_accuracy: 0.6638
# Epoch 21/30
# 1302/1302 [==============================] - 90s 69ms/step - loss: 1.7324 - accuracy: 0.7415 - val_loss: 2.3251 - val_accuracy: 0.6720
# Epoch 22/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 1.7172 - accuracy: 0.7442 - val_loss: 2.3322 - val_accuracy: 0.6704
# Epoch 23/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 1.7057 - accuracy: 0.7465 - val_loss: 2.3392 - val_accuracy: 0.6701
# Epoch 24/30
# 1302/1302 [==============================] - 89s 69ms/step - loss: 1.6910 - accuracy: 0.7489 - val_loss: 2.3581 - val_accuracy: 0.6667
# Epoch 25/30
# 1302/1302 [==============================] - 90s 69ms/step - loss: 1.6775 - accuracy: 0.7512 - val_loss: 2.4016 - val_accuracy: 0.6726
# Epoch 26/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 1.6670 - accuracy: 0.7534 - val_loss: 2.3955 - val_accuracy: 0.6718
# Epoch 27/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 1.6529 - accuracy: 0.7560 - val_loss: 2.3974 - val_accuracy: 0.6717
# Epoch 28/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 1.6408 - accuracy: 0.7580 - val_loss: 2.4278 - val_accuracy: 0.6691
# Epoch 29/30
# 1302/1302 [==============================] - 88s 68ms/step - loss: 1.6297 - accuracy: 0.7599 - val_loss: 2.4438 - val_accuracy: 0.6698
# Epoch 30/30
# 1302/1302 [==============================] - 89s 68ms/step - loss: 1.6187 - accuracy: 0.7622 - val_loss: 2.4239 - val_accuracy: 0.6721

# %% [markdown]
# **Translating new sentences with our Transformer model**

# %%
import numpy as np
spa_vocab = target_vectorization.get_vocabulary()
spa_index_lookup = dict(zip(range(len(spa_vocab)), spa_vocab))
max_decoded_sentence_length = 20

def decode_sequence(input_sentence):
    tokenized_input_sentence = source_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = target_vectorization(
            [decoded_sentence])[:, :-1]
        predictions = transformer(
            [tokenized_input_sentence, tokenized_target_sentence])
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token
        if sampled_token == "[end]":
            break
    return decoded_sentence

test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(20):
    input_sentence = random.choice(test_eng_texts)
    print("-")
    print(input_sentence)
    print(decode_sequence(input_sentence))
# Out:
# -
# Everybody says that he's an effeminate guy.
# [start] todo el mundo dice que es un tipo de [UNK] [end]
# -
# Tom doesn't know anything about what happened.
# [start] tom no sabe nada acerca de qué ocurrió [end]
# -
# My cousin is already four years old.
# [start] mi primo tiene cuatro años [end]
# -
# Tom saw the pictures.
# [start] tom vio las fotos [end]
# -
# Let's get along.
# [start] [UNK] [end]
# -
# That book contains useful ideas.
# [start] ese libro recuerda ideas [end]
# -
# I can't open the door.
# [start] no puedo parar la puerta [end]
# -
# I have to deal with this issue.
# [start] tengo que [UNK] esto [end]
# -
# Tom is romantic.
# [start] tom es mala [end]
# -
# I blamed him for the accident.
# [start] lo [UNK] por su accidente [end]
# -
# Don't close your eyes.
# [start] no te [UNK] los ojos [end]
# -
# I've got nothing to say to him.
# [start] no tengo nada que decirle [end]
# -
# Why is Tom so gloomy?
# [start] por qué tom está tan triste [end]
# -
# You're in danger.
# [start] estás en peligro [end]
# -
# If I were more creative, I would try to write music.
# [start] si me [UNK] los [UNK] la [UNK] de escribir [end]
# -
# Tom doesn't seem to know what he wants.
# [start] tom no parece saber qué quiere [end]
# -
# He has a strong personality.
# [start] Él tiene una caja fuerte [end]
# -
# Does every boy have to learn cooking in your school?
# [start] todos los perros tienen que aprender en la escuela de cocinar [end]
# -
# Lay it on the table.
# [start] [UNK] en la mesa [end]
# -
# I like her very much.
# [start] me gusta mucho [end]

# %% [markdown]
# ## Summary
