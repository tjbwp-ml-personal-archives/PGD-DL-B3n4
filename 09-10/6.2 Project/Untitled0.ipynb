# %% [markdown]
# Face Bank

# %% [markdown]
# Generate Embeddings

# %% [markdown]
# Acquire Object Image

# %% [markdown]
# Generate Embedding

# %% [markdown]
# Loop over to comapre Object Embedding with Face Bank Embeddings

# %% [markdown]
# Check for best similarity

# %% [markdown]
# Dsiplay
